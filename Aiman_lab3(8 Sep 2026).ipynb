# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6LuZJvj-_WnBFAnZgsRUIVc0pNiU0pxaUWeGl6zZr9rfw")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# make a 3 day travel plan for hunza.Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: exit
# Goodbye

# %%
def movie_agent(user_input):

    prompt = f"""
You are a professional movie recommendation agent called CineMind.

Provide a simple and well-structured movie recommendation with:

1. Recommended Movies
2. Genre
3. Language
4. Rating
5. Short Reason for Recommendation

Consider the user's preferences, such as genre, mood, language,
favorite movies, and budget/age suitability.

Keep the response simple and easy for students to understand.

User request: {user_input}

Movie Recommendation:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("CineMind Movie Recommendation Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye!")
        break

    try:
        reply = movie_agent(user)
        print("\nCineMind:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# CineMind Movie Recommendation Agent Started (type 'exit' to stop)
#
# You: exit
# Goodbye!
